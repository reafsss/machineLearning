# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
df=pd.read_csv('D:\\data3.csv')
print(df.shape)
df.head()
# Out:
# (365, 13)
#          date  counts  tem_average  tem_min  tem_max  Daily precipitation  \
# 0  2019-04-01   37660          5.5      0.3     11.3                  NaN
# 1  2019-04-02   42029          6.7      1.3     13.0                  NaN
# 2  2019-04-03   43257          7.6      1.9     13.6                  NaN
# 3  2019-04-04   45681          9.2      3.0     15.7                  NaN
# 4  2019-04-05   45643         11.4      7.0     17.2                  0.0
#
#    windSpeed_max  windSpeed_average  dewPointTemperature_average  \
# 0            5.8                2.5                         -8.4
# 1            6.1                2.2                         -8.0
# 2            5.0                2.3                         -7.3
# 3            5.0                2.5                         -3.7
# 4            5.4                2.9                         -4.1
#
#    relativeHumidity_average  Insolation_sum  Totalcloud_average  season
# 0                      39.8           23.42                 1.3       1
# 1                      36.9           22.96                 0.3       1
# 2                      36.1           22.61                 0.3       1
# 3                      43.0           22.72                 0.0       1
# 4                      41.0           20.11                 3.0       1

# %%
df.describe()
# Out:
#              counts  tem_average     tem_min     tem_max  Daily precipitation  \
# count    365.000000   365.000000  365.000000  365.000000           147.000000
# mean   55589.000000    13.960822    9.722192   18.884932             6.602721
# std    24830.107765     9.807559    9.920191   10.062487            12.373563
# min     1920.000000    -8.300000  -11.800000   -4.900000             0.000000
# 25%    32972.000000     5.500000    0.800000    9.900000             0.000000
# 50%    57020.000000    14.700000    9.500000   20.200000             1.200000
# 75%    78874.000000    23.000000   18.900000   27.800000             7.500000
# max    95859.000000    31.600000   27.900000   36.800000            63.200000
#
#        windSpeed_max  windSpeed_average  dewPointTemperature_average  \
# count     365.000000         365.000000                   365.000000
# mean        4.396164           2.050959                     4.972603
# std         1.129785           0.670968                    11.010800
# min         2.000000           0.600000                   -20.400000
# 25%         3.600000           1.600000                    -4.500000
# 50%         4.300000           1.900000                     5.200000
# 75%         5.000000           2.300000                    14.200000
# max        11.800000           6.000000                    25.000000
#
#        relativeHumidity_average  Insolation_sum  Totalcloud_average  \
# count                365.000000      363.000000          365.000000
# mean                  58.106027       13.928430            4.918904
# std                   14.768104        7.062214            3.035070
# min                   17.900000        0.750000            0.000000
# 25%                   46.800000        8.915000            2.300000
# 50%                   58.000000       13.150000            5.000000
# 75%                   67.300000       19.850000            7.500000
# max                   95.300000       28.890000           10.000000
#
#            season
# count  365.000000
# mean     2.660274
# std      1.106765
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      4.000000
# max      4.000000

# %%
n=df.isnull().sum()
n
# Out:
# date                             0
# counts                           0
# tem_average                      0
# tem_min                          0
# tem_max                          0
# Daily precipitation            218
# windSpeed_max                    0
# windSpeed_average                0
# dewPointTemperature_average      0
# relativeHumidity_average         0
# Insolation_sum                   2
# Totalcloud_average               0
# season                           0
# dtype: int64

# %%
n.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Daily precipitation'].describe()
# Out:
# count    147.000000
# mean       6.602721
# std       12.373563
# min        0.000000
# 25%        0.000000
# 50%        1.200000
# 75%        7.500000
# max       63.200000
# Name: Daily precipitation, dtype: float64

# %%
df['Insolation_sum'].describe()
# Out:
# count    363.000000
# mean      13.928430
# std        7.062214
# min        0.750000
# 25%        8.915000
# 50%       13.150000
# 75%       19.850000
# max       28.890000
# Name: Insolation_sum, dtype: float64

# %%
drop_column=[ 'Daily precipitation']
df.drop(drop_column, axis=1, inplace=True)

# %%
n=df.isnull().sum()
n
# Out:
# date                           0
# counts                         0
# tem_average                    0
# tem_min                        0
# tem_max                        0
# windSpeed_max                  0
# windSpeed_average              0
# dewPointTemperature_average    0
# relativeHumidity_average       0
# Insolation_sum                 2
# Totalcloud_average             0
# season                         0
# dtype: int64

# %%
df=df.fillna(0)

# %%
n=df.isnull().sum()
n
# Out:
# date                           0
# counts                         0
# tem_average                    0
# tem_min                        0
# tem_max                        0
# windSpeed_max                  0
# windSpeed_average              0
# dewPointTemperature_average    0
# relativeHumidity_average       0
# Insolation_sum                 0
# Totalcloud_average             0
# season                         0
# dtype: int64

# %%
sns.lineplot(data=df, x="date", y="counts")
# Out:
# <AxesSubplot:xlabel='date', ylabel='counts'>

# %%
#문자열을 datetime 타입으로 변경
df['date'] = pd.to_datetime(df['date'], format="%Y-%m-%d")
# year, month, day 추출
df['year'] = pd.to_datetime(df['date'], format="%Y-%m-%d").apply(lambda x:x.year)
df['month'] = pd.to_datetime(df['date'], format="%Y-%m-%d").apply(lambda x:x.month)
df['day'] = pd.to_datetime(df['date'], format="%Y-%m-%d").apply(lambda x:x.day)
df.head(3)
# Out:
#         date  counts  tem_average  tem_min  tem_max  windSpeed_max  \
# 0 2019-04-01   37660          5.5      0.3     11.3            5.8
# 1 2019-04-02   42029          6.7      1.3     13.0            6.1
# 2 2019-04-03   43257          7.6      1.9     13.6            5.0
#
#    windSpeed_average  dewPointTemperature_average  relativeHumidity_average  \
# 0                2.5                         -8.4                      39.8
# 1                2.2                         -8.0                      36.9
# 2                2.3                         -7.3                      36.1
#
#    Insolation_sum  Totalcloud_average  season  year  month  day
# 0           23.42                 1.3       1  2019      4    1
# 1           22.96                 0.3       1  2019      4    2
# 2           22.61                 0.3       1  2019      4    3

# %%
drop_columns=['date']
df.drop(drop_columns, axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    counts  tem_average  tem_min  tem_max  windSpeed_max  windSpeed_average  \
# 0   37660          5.5      0.3     11.3            5.8                2.5
# 1   42029          6.7      1.3     13.0            6.1                2.2
# 2   43257          7.6      1.9     13.6            5.0                2.3
#
#    dewPointTemperature_average  relativeHumidity_average  Insolation_sum  \
# 0                         -8.4                      39.8           23.42
# 1                         -8.0                      36.9           22.96
# 2                         -7.3                      36.1           22.61
#
#    Totalcloud_average  season  year  month  day
# 0                 1.3       1  2019      4    1
# 1                 0.3       1  2019      4    2
# 2                 0.3       1  2019      4    3

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def rmsle(y, pred):
    log_y=np.log1p(y)
    log_pred=np.log1p(pred)
    squared_error=(log_y - log_pred)**2
    rmsle=np.sqrt(np.mean(squared_error))
    return rmsle

def rmse(y, pred):
    return np.sqrt(mean_squared_error(y, pred))

def evaluate_regr(y, pred):
    rmsle_val = rmsle(y, pred)
    rmse_val = rmse(y, pred)
    mae_val = mean_absolute_error(y, pred)
    print('RMSLE: {0:.3f}, RMSE: {1:.3f}, MAE: {2:.3f}'.format(rmsle_val, rmse_val, mae_val))

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso

y_target = df['counts']
X_features = df.drop(['counts'],axis=1,inplace=False)

X_train, X_test, y_train, y_test=train_test_split(X_features, y_target, test_size=0.3, random_state=0)

lr_reg=LinearRegression()
lr_reg.fit(X_train, y_train)
pred=lr_reg.predict(X_test)

evaluate_regr(y_test,pred)
# Out:
# RMSLE: 0.353, RMSE: 14603.215, MAE: 10763.334

# %%
def get_top_error_data(y_test, pred, n_tops=5):
    result_df = pd.DataFrame(y_test.values, columns=['real_count'])
    result_df['predicted_count']=np.round(pred)
    result_df['diff']=np.abs(result_df['real_count']-result_df['predicted_count'])
    
    print(result_df.sort_values('diff', ascending=False)[:n_tops])
    
get_top_error_data(y_test,pred,n_tops=5)
# Out:
#      real_count  predicted_count     diff
# 101       16631          65631.0  49000.0
# 37        43351          92149.0  48798.0
# 30        49047          84623.0  35576.0
# 27        12644          45789.0  33145.0
# 96        22789          54239.0  31450.0

# %%
y_target.hist()
# Out:
# <AxesSubplot:>

# %%
coef=pd.Series(lr_reg.coef_, index=X_features.columns)
coef_sort = coef.sort_values(ascending=False)
sns.barplot(x=coef_sort.values,y=coef_sort.index)
# Out:
# <AxesSubplot:>

# %%
X_features_ohe = pd.get_dummies(X_features, columns=['month','day','season'])

# %%
X_train, X_test, y_train, y_test=train_test_split(X_features_ohe, y_target, test_size=0.3, random_state=0)

def get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1=False):
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    if is_expm1:
        y_test = np.expm1(y_test)
        pred = np.expm1(pred)
    print('###',model.__class__.__name__,'###')
    evaluate_regr(y_test, pred)
    
lr_reg=LinearRegression()
ridge_reg=Ridge(alpha=10)
lasso_reg=Lasso(alpha=0.01)

for model in [lr_reg, ridge_reg, lasso_reg]:
    get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1=True)
# Out:
# ### LinearRegression ###
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-260-2566acd30509> in <module>
#      15
#      16 for model in [lr_reg, ridge_reg, lasso_reg]:
# ---> 17     get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1=True)
#
# <ipython-input-260-2566acd30509> in get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1)
#       8         pred = np.expm1(pred)
#       9     print('###',model.__class__.__name__,'###')
# ---> 10     evaluate_regr(y_test, pred)
#      11
#      12 lr_reg=LinearRegression()
#
# <ipython-input-254-79c2bea79ad4> in evaluate_regr(y, pred)
#      13 def evaluate_regr(y, pred):
#      14     rmsle_val = rmsle(y, pred)
# ---> 15     rmse_val = rmse(y, pred)
#      16     mae_val = mean_absolute_error(y, pred)
#      17     print('RMSLE: {0:.3f}, RMSE: {1:.3f}, MAE: {2:.3f}'.format(rmsle_val, rmse_val, mae_val))
#
# <ipython-input-254-79c2bea79ad4> in rmse(y, pred)
#       9
#      10 def rmse(y, pred):
# ---> 11     return np.sqrt(mean_squared_error(y, pred))
#      12
#      13 def evaluate_regr(y, pred):
#
# D:\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# D:\Ana\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     254         y_true, y_pred, multioutput)
#     255     check_consistent_length(y_true, y_pred, sample_weight)
#
# D:\Ana\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      87
#
# D:\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# D:\Ana\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643
#     644         if force_all_finite:
# --> 645             _assert_all_finite(array,
#     646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#
# D:\Ana\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      95                 not allow_nan and not np.isfinite(X).all()):
#      96             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 97             raise ValueError(
#      98                     msg_err.format
#      99                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
drop_column=[ 'Daily precipitation']
df.drop(drop_column, axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso

y_target = df['counts']
X_features = df.drop(['counts'],axis=1,inplace=False)

X_train, X_test, y_train, y_test=train_test_split(X_features_ohe, y_target, test_size=0.3, random_state=0)

lr_reg=LinearRegression()
lr_reg.fit(X_train, y_train)
pred=lr_reg.predict(X_test)

evaluate_regr(y_test,pred)
# Out:
# RMSLE: 0.391, RMSE: 15464.624, MAE: 11407.073

# %%
y_target.hist()
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(30,15))
coef=pd.Series(lr_reg.coef_, index=X_features_ohe.columns)
coef_sort = coef.sort_values(ascending=False)
sns.barplot(x=coef_sort.values,y=coef_sort.index)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr(method = 'pearson')
corr
# Out:
#                                counts  tem_average   tem_min   tem_max  \
# counts                       1.000000     0.690049  0.644776  0.719930
# tem_average                  0.690049     1.000000  0.987227  0.987420
# tem_min                      0.644776     0.987227  1.000000  0.955060
# tem_max                      0.719930     0.987420  0.955060  1.000000
# windSpeed_max               -0.139845    -0.236514 -0.228596 -0.242347
# windSpeed_average           -0.158333    -0.270503 -0.238371 -0.294976
# dewPointTemperature_average  0.554774     0.935466  0.959281  0.891400
# relativeHumidity_average    -0.050111     0.304075  0.395199  0.214062
# Insolation_sum               0.527041     0.365494  0.264350  0.461004
# Totalcloud_average          -0.094651     0.285077  0.363853  0.188727
# season                      -0.392507    -0.502938 -0.465047 -0.522391
# year                        -0.502788    -0.599102 -0.582509 -0.591168
# month                        0.264593     0.239309  0.240223  0.221573
# day                          0.081979     0.039059  0.041591  0.026971
#
#                              windSpeed_max  windSpeed_average  \
# counts                           -0.139845          -0.158333
# tem_average                      -0.236514          -0.270503
# tem_min                          -0.228596          -0.238371
# tem_max                          -0.242347          -0.294976
# windSpeed_max                     1.000000           0.836521
# windSpeed_average                 0.836521           1.000000
# dewPointTemperature_average      -0.247991          -0.258665
# relativeHumidity_average         -0.126303          -0.086439
# Insolation_sum                   -0.026526          -0.102106
# Totalcloud_average               -0.097804          -0.014572
# season                           -0.005879           0.098846
# year                              0.216942           0.231208
# month                            -0.141818          -0.076399
# day                               0.005289           0.003655
#
#                              dewPointTemperature_average  \
# counts                                          0.554774
# tem_average                                     0.935466
# tem_min                                         0.959281
# tem_max                                         0.891400
# windSpeed_max                                  -0.247991
# windSpeed_average                              -0.258665
# dewPointTemperature_average                     1.000000
# relativeHumidity_average                        0.615744
# Insolation_sum                                  0.099368
# Totalcloud_average                              0.460957
# season                                         -0.363629
# year                                           -0.563912
# month                                           0.288756
# day                                             0.051498
#
#                              relativeHumidity_average  Insolation_sum  \
# counts                                      -0.050111        0.527041
# tem_average                                  0.304075        0.365494
# tem_min                                      0.395199        0.264350
# tem_max                                      0.214062        0.461004
# windSpeed_max                               -0.126303       -0.026526
# windSpeed_average                           -0.086439       -0.102106
# dewPointTemperature_average                  0.615744        0.099368
# relativeHumidity_average                     1.000000       -0.538966
# Insolation_sum                              -0.538966        1.000000
# Totalcloud_average                           0.626429       -0.570688
# season                                       0.094201       -0.504524
# year                                        -0.191410       -0.168315
# month                                        0.225652       -0.159041
# day                                          0.037345       -0.090937
#
#                              Totalcloud_average    season      year     month  \
# counts                                -0.094651 -0.392507 -0.502788  0.264593
# tem_average                            0.285077 -0.502938 -0.599102  0.239309
# tem_min                                0.363853 -0.465047 -0.582509  0.240223
# tem_max                                0.188727 -0.522391 -0.591168  0.221573
# windSpeed_max                         -0.097804 -0.005879  0.216942 -0.141818
# windSpeed_average                     -0.014572  0.098846  0.231208 -0.076399
# dewPointTemperature_average            0.460957 -0.363629 -0.563912  0.288756
# relativeHumidity_average               0.626429  0.094201 -0.191410  0.225652
# Insolation_sum                        -0.570688 -0.504524 -0.168315 -0.159041
# Totalcloud_average                     1.000000 -0.017957 -0.132304  0.058631
# season                                -0.017957  1.000000  0.165679  0.266904
# year                                  -0.132304  0.165679  1.000000 -0.752071
# month                                  0.058631  0.266904 -0.752071  1.000000
# day                                    0.079903 -0.007364 -0.006508  0.008422
#
#                                   day
# counts                       0.081979
# tem_average                  0.039059
# tem_min                      0.041591
# tem_max                      0.026971
# windSpeed_max                0.005289
# windSpeed_average            0.003655
# dewPointTemperature_average  0.051498
# relativeHumidity_average     0.037345
# Insolation_sum              -0.090937
# Totalcloud_average           0.079903
# season                      -0.007364
# year                        -0.006508
# month                        0.008422
# day                          1.000000

# %%
plt.subplots(figsize=(12,6))
df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Reds')

# %%
df_add = pd.get_dummies(df, columns=['year','month','day'])

# %%
corr = df_add.corr(method = 'pearson')
corr
# Out:
#                                counts  tem_average   tem_min   tem_max  \
# counts                       1.000000     0.690049  0.644776  0.719930
# tem_average                  0.690049     1.000000  0.987227  0.987420
# tem_min                      0.644776     0.987227  1.000000  0.955060
# tem_max                      0.719930     0.987420  0.955060  1.000000
# windSpeed_max               -0.139845    -0.236514 -0.228596 -0.242347
# windSpeed_average           -0.158333    -0.270503 -0.238371 -0.294976
# dewPointTemperature_average  0.554774     0.935466  0.959281  0.891400
# relativeHumidity_average    -0.050111     0.304075  0.395199  0.214062
# Insolation_sum               0.527041     0.365494  0.264350  0.461004
# Totalcloud_average          -0.094651     0.285077  0.363853  0.188727
# year_2019                    0.502788     0.599102  0.582509  0.591168
# year_2020                   -0.502788    -0.599102 -0.582509 -0.591168
# month_1                     -0.368234    -0.395532 -0.362870 -0.406780
# month_2                     -0.347191    -0.346676 -0.330243 -0.345352
# month_3                     -0.075194    -0.197859 -0.220713 -0.175582
# month_4                     -0.080324    -0.056245 -0.076894 -0.037074
# month_5                      0.201987     0.169792  0.123221  0.204858
# month_6                      0.251915     0.261011  0.251864  0.262714
# month_7                      0.174715     0.370676  0.398607  0.339625
# month_8                      0.149785     0.411515  0.426483  0.386569
# month_9                      0.192895     0.260693  0.276672  0.237354
# month_10                     0.282644     0.082596  0.071834  0.097376
# month_11                    -0.052458    -0.184064 -0.190172 -0.166916
# month_12                    -0.333390    -0.378173 -0.369616 -0.399152
# day_1                        0.007680    -0.012283 -0.013441 -0.009662
# day_2                       -0.001742     0.005287  0.001603  0.008074
# day_3                        0.017210    -0.000517  0.003775 -0.005534
# day_4                       -0.009314     0.003404  0.000518  0.015108
# day_5                       -0.012177     0.011248  0.006411  0.023059
# day_6                       -0.069874    -0.023265 -0.016543 -0.029692
# day_7                       -0.077791    -0.047072 -0.055232 -0.039445
# day_8                        0.013752    -0.008675 -0.003360 -0.016084
# day_9                        0.002953    -0.013224 -0.013596 -0.006451
# day_10                      -0.097227    -0.014479 -0.018094 -0.010121
# day_11                       0.014703     0.003091  0.008272  0.003182
# day_12                      -0.022809     0.012974  0.004240  0.016484
# day_13                       0.002665     0.001208  0.008272 -0.005687
# day_14                      -0.013604    -0.001145 -0.001344 -0.003852
# day_15                      -0.042290    -0.021068 -0.017939 -0.024647
# day_16                       0.027270     0.006542 -0.003980  0.010368
# day_17                       0.014536    -0.001929 -0.003825  0.007004
# day_18                       0.012434    -0.006008  0.007652 -0.018836
# day_19                      -0.016768    -0.013224 -0.014372 -0.005228
# day_20                       0.030750    -0.015734 -0.011115 -0.022659
# day_21                       0.008526    -0.018401 -0.009098 -0.020518
# day_22                       0.034031     0.012346 -0.003980  0.021683
# day_23                       0.065660     0.035721  0.030606  0.037279
# day_24                       0.040304     0.034780  0.038826  0.032386
# day_25                      -0.011082     0.024896  0.018819  0.029328
# day_26                      -0.019232     0.011562  0.014631  0.001958
# day_27                      -0.004847     0.015170  0.007032  0.018930
# day_28                       0.000550    -0.000674  0.013701 -0.012873
# day_29                       0.030709    -0.000047  0.008117 -0.010274
# day_30                       0.063264     0.018376  0.018855  0.016850
# day_31                       0.014512    -0.000053 -0.008984 -0.001381
#
#                              windSpeed_max  windSpeed_average  \
# counts                           -0.139845          -0.158333
# tem_average                      -0.236514          -0.270503
# tem_min                          -0.228596          -0.238371
# tem_max                          -0.242347          -0.294976
# windSpeed_max                     1.000000           0.836521
# windSpeed_average                 0.836521           1.000000
# dewPointTemperature_average      -0.247991          -0.258665
# relativeHumidity_average         -0.126303          -0.086439
# Insolation_sum                   -0.026526          -0.102106
# Totalcloud_average               -0.097804          -0.014572
# year_2019                        -0.216942          -0.231208
# year_2020                         0.216942           0.231208
# month_1                           0.040233           0.029631
# month_2                           0.073729           0.119776
# month_3                           0.224897           0.212968
# month_4                           0.016048          -0.077841
# month_5                           0.049815           0.003231
# month_6                          -0.104194          -0.140367
# month_7                          -0.120912          -0.100905
# month_8                          -0.155754          -0.209440
# month_9                          -0.029530           0.066859
# month_10                         -0.011159           0.025231
# month_11                          0.052297           0.060609
# month_12                         -0.034678           0.013498
# day_1                             0.038758           0.004322
# day_2                            -0.023886          -0.087400
# day_3                             0.026502          -0.007143
# day_4                             0.001989           0.029546
# day_5                             0.057824           0.029546
# day_6                            -0.048399           0.015788
# day_7                            -0.042012          -0.006231
# day_8                             0.083698           0.123562
# day_9                             0.029225           0.013495
# day_10                           -0.105596          -0.050711
# day_11                           -0.094701          -0.062177
# day_12                            0.030587           0.041011
# day_13                            0.036034           0.002029
# day_14                            0.015607          -0.004850
# day_15                           -0.012991          -0.036953
# day_16                            0.018331          -0.020901
# day_17                           -0.034781           0.002029
# day_18                            0.015607           0.002029
# day_19                           -0.032057           0.011201
# day_20                            0.067356           0.082286
# day_21                           -0.010268           0.002029
# day_22                           -0.070188          -0.073642
# day_23                            0.026502           0.043304
# day_24                           -0.030695          -0.043832
# day_25                           -0.062017          -0.080521
# day_26                            0.007436          -0.046125
# day_27                           -0.004820          -0.030074
# day_28                            0.029225           0.082286
# day_29                            0.012883          -0.007143
# day_30                            0.034688           0.060735
# day_31                            0.051821           0.019178
#
#                              dewPointTemperature_average  \
# counts                                          0.554774
# tem_average                                     0.935466
# tem_min                                         0.959281
# tem_max                                         0.891400
# windSpeed_max                                  -0.247991
# windSpeed_average                              -0.258665
# dewPointTemperature_average                     1.000000
# relativeHumidity_average                        0.615744
# Insolation_sum                                  0.099368
# Totalcloud_average                              0.460957
# year_2019                                       0.563912
# year_2020                                      -0.563912
# month_1                                        -0.343072
# month_2                                        -0.286534
# month_3                                        -0.254053
# month_4                                        -0.116825
# month_5                                         0.039280
# month_6                                         0.239243
# month_7                                         0.390440
# month_8                                         0.426191
# month_9                                         0.272796
# month_10                                        0.101218
# month_11                                       -0.161277
# month_12                                       -0.308394
# day_1                                          -0.002475
# day_2                                           0.004651
# day_3                                          -0.003453
# day_4                                           0.008843
# day_5                                          -0.005270
# day_6                                          -0.050543
# day_7                                          -0.066310
# day_8                                          -0.011138
# day_9                                          -0.020780
# day_10                                         -0.010999
# day_11                                          0.025891
# day_12                                          0.013035
# day_13                                         -0.002894
# day_14                                         -0.003593
# day_15                                         -0.020221
# day_16                                          0.001577
# day_17                                          0.000320
# day_18                                          0.021140
# day_19                                         -0.002615
# day_20                                         -0.004571
# day_21                                         -0.009322
# day_22                                         -0.000658
# day_23                                         -0.001078
# day_24                                          0.027847
# day_25                                          0.031061
# day_26                                          0.027148
# day_27                                          0.040004
# day_28                                          0.000180
# day_29                                         -0.002056
# day_30                                          0.007726
# day_31                                          0.007979
#
#                              relativeHumidity_average  Insolation_sum  \
# counts                                      -0.050111        0.527041
# tem_average                                  0.304075        0.365494
# tem_min                                      0.395199        0.264350
# tem_max                                      0.214062        0.461004
# windSpeed_max                               -0.126303       -0.026526
# windSpeed_average                           -0.086439       -0.102106
# dewPointTemperature_average                  0.615744        0.099368
# relativeHumidity_average                     1.000000       -0.538966
# Insolation_sum                              -0.538966        1.000000
# Totalcloud_average                           0.626429       -0.570688
# year_2019                                    0.191410        0.168315
# year_2020                                   -0.191410       -0.168315
# month_1                                     -0.067028       -0.242147
# month_2                                     -0.008775       -0.136797
# month_3                                     -0.221493        0.113658
# month_4                                     -0.145340        0.121472
# month_5                                     -0.240019        0.376039
# month_6                                      0.050741        0.243426
# month_7                                      0.226975       -0.003353
# month_8                                      0.215047        0.078567
# month_9                                      0.145643       -0.047462
# month_10                                     0.075309       -0.035887
# month_11                                    -0.023660       -0.180971
# month_12                                    -0.005056       -0.289336
# day_1                                        0.012114        0.056450
# day_2                                        0.012635        0.021821
# day_3                                       -0.013827        0.007035
# day_4                                        0.017740        0.037579
# day_5                                       -0.033622        0.053229
# day_6                                       -0.085713        0.007987
# day_7                                       -0.069398        0.022538
# day_8                                        0.004613       -0.036651
# day_9                                       -0.013723        0.008721
# day_10                                      -0.003930       -0.011295
# day_11                                       0.071081       -0.035981
# day_12                                       0.006592        0.037385
# day_13                                      -0.008827       -0.016613
# day_14                                      -0.008618        0.019184
# day_15                                      -0.005493        0.001610
# day_16                                       0.003884        0.028652
# day_17                                       0.005863        0.024739
# day_18                                       0.069206       -0.093113
# day_19                                       0.020344        0.019292
# day_20                                       0.001800        0.036434
# day_21                                       0.013260       -0.007188
# day_22                                      -0.032059        0.022599
# day_23                                      -0.081442        0.024134
# day_24                                      -0.014348        0.011294
# day_25                                       0.032534       -0.012246
# day_26                                       0.053162       -0.063866
# day_27                                       0.069206       -0.046746
# day_28                                      -0.009973       -0.065077
# day_29                                      -0.000909       -0.071043
# day_30                                      -0.031910        0.014467
# day_31                                       0.020260        0.008052
#
#                              Totalcloud_average  ...    day_22    day_23  \
# counts                                -0.094651  ...  0.034031  0.065660
# tem_average                            0.285077  ...  0.012346  0.035721
# tem_min                                0.363853  ... -0.003980  0.030606
# tem_max                                0.188727  ...  0.021683  0.037279
# windSpeed_max                         -0.097804  ... -0.070188  0.026502
# windSpeed_average                     -0.014572  ... -0.073642  0.043304
# dewPointTemperature_average            0.460957  ... -0.000658 -0.001078
# relativeHumidity_average               0.626429  ... -0.032059 -0.081442
# Insolation_sum                        -0.570688  ...  0.022599  0.024134
# Totalcloud_average                     1.000000  ...  0.015072  0.011016
# year_2019                              0.132304  ... -0.000292 -0.000292
# year_2020                             -0.132304  ...  0.000292  0.000292
# month_1                               -0.025570  ... -0.001057 -0.001057
# month_2                               -0.017876  ...  0.002646  0.002646
# month_3                               -0.162401  ... -0.001057 -0.001057
# month_4                                0.000766  ...  0.000766  0.000766
# month_5                               -0.116359  ... -0.001057 -0.001057
# month_6                                0.051450  ...  0.000766  0.000766
# month_7                                0.227017  ... -0.001057 -0.001057
# month_8                                0.071703  ... -0.001057 -0.001057
# month_9                                0.180997  ...  0.002646  0.002646
# month_10                              -0.085555  ... -0.001057 -0.001057
# month_11                              -0.084474  ...  0.000766  0.000766
# month_12                              -0.035297  ... -0.001057 -0.001057
# day_1                                 -0.059954  ... -0.033994 -0.033994
# day_2                                 -0.031059  ... -0.033994 -0.033994
# day_3                                 -0.018386  ... -0.033994 -0.033994
# day_4                                 -0.045760  ... -0.033994 -0.033994
# day_5                                 -0.073641  ... -0.033994 -0.033994
# day_6                                 -0.043732  ... -0.033994 -0.033994
# day_7                                 -0.010088  ... -0.032501 -0.032501
# day_8                                  0.105813  ... -0.033994 -0.033994
# day_9                                 -0.012302  ... -0.033994 -0.033994
# day_10                                 0.023183  ... -0.033994 -0.033994
# day_11                                 0.081480  ... -0.033994 -0.033994
# day_12                                -0.048802  ... -0.033994 -0.033994
# day_13                                 0.016593  ... -0.033994 -0.033994
# day_14                                 0.010003  ... -0.033994 -0.033994
# day_15                                -0.075669  ... -0.033994 -0.033994
# day_16                                -0.029031  ... -0.033994 -0.033994
# day_17                                 0.031801  ... -0.033994 -0.033994
# day_18                                 0.108347  ... -0.033994 -0.033994
# day_19                                -0.023962  ... -0.033994 -0.033994
# day_20                                -0.028524  ... -0.033994 -0.033994
# day_21                                -0.051843  ... -0.033994 -0.033994
# day_22                                 0.015072  ...  1.000000 -0.033994
# day_23                                 0.011016  ... -0.033994  1.000000
# day_24                                -0.042211  ... -0.033994 -0.033994
# day_25                                -0.023962  ... -0.033994 -0.033994
# day_26                                 0.113923  ... -0.033994 -0.033994
# day_27                                 0.083001  ... -0.033994 -0.033994
# day_28                                 0.030787  ... -0.033994 -0.033994
# day_29                                 0.029266  ... -0.033994 -0.033994
# day_30                                -0.004801  ... -0.032501 -0.032501
# day_31                                -0.048326  ... -0.025782 -0.025782
#
#                                day_24    day_25    day_26    day_27    day_28  \
# counts                       0.040304 -0.011082 -0.019232 -0.004847  0.000550
# tem_average                  0.034780  0.024896  0.011562  0.015170 -0.000674
# tem_min                      0.038826  0.018819  0.014631  0.007032  0.013701
# tem_max                      0.032386  0.029328  0.001958  0.018930 -0.012873
# windSpeed_max               -0.030695 -0.062017  0.007436 -0.004820  0.029225
# windSpeed_average           -0.043832 -0.080521 -0.046125 -0.030074  0.082286
# dewPointTemperature_average  0.027847  0.031061  0.027148  0.040004  0.000180
# relativeHumidity_average    -0.014348  0.032534  0.053162  0.069206 -0.009973
# Insolation_sum               0.011294 -0.012246 -0.063866 -0.046746 -0.065077
# Totalcloud_average          -0.042211 -0.023962  0.113923  0.083001  0.030787
# year_2019                   -0.000292 -0.000292 -0.000292 -0.000292 -0.000292
# year_2020                    0.000292  0.000292  0.000292  0.000292  0.000292
# month_1                     -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_2                      0.002646  0.002646  0.002646  0.002646  0.002646
# month_3                     -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_4                      0.000766  0.000766  0.000766  0.000766  0.000766
# month_5                     -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_6                      0.000766  0.000766  0.000766  0.000766  0.000766
# month_7                     -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_8                     -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_9                      0.002646  0.002646  0.002646  0.002646  0.002646
# month_10                    -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# month_11                     0.000766  0.000766  0.000766  0.000766  0.000766
# month_12                    -0.001057 -0.001057 -0.001057 -0.001057 -0.001057
# day_1                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_2                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_3                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_4                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_5                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_6                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_7                       -0.032501 -0.032501 -0.032501 -0.032501 -0.032501
# day_8                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_9                       -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_10                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_11                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_12                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_13                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_14                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_15                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_16                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_17                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_18                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_19                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_20                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_21                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_22                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_23                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_24                       1.000000 -0.033994 -0.033994 -0.033994 -0.033994
# day_25                      -0.033994  1.000000 -0.033994 -0.033994 -0.033994
# day_26                      -0.033994 -0.033994  1.000000 -0.033994 -0.033994
# day_27                      -0.033994 -0.033994 -0.033994  1.000000 -0.033994
# day_28                      -0.033994 -0.033994 -0.033994 -0.033994  1.000000
# day_29                      -0.033994 -0.033994 -0.033994 -0.033994 -0.033994
# day_30                      -0.032501 -0.032501 -0.032501 -0.032501 -0.032501
# day_31                      -0.025782 -0.025782 -0.025782 -0.025782 -0.025782
#
#                                day_29    day_30    day_31
# counts                       0.030709  0.063264  0.014512
# tem_average                 -0.000047  0.018376 -0.000053
# tem_min                      0.008117  0.018855 -0.008984
# tem_max                     -0.010274  0.016850 -0.001381
# windSpeed_max                0.012883  0.034688  0.051821
# windSpeed_average           -0.007143  0.060735  0.019178
# dewPointTemperature_average -0.002056  0.007726  0.007979
# relativeHumidity_average    -0.000909 -0.031910  0.020260
# Insolation_sum              -0.071043  0.014467  0.008052
# Totalcloud_average           0.029266 -0.004801 -0.048326
# year_2019                   -0.000292  0.027503 -0.011765
# year_2020                    0.000292 -0.027503  0.011765
# month_1                     -0.001057  0.003780  0.029055
# month_2                      0.002646 -0.051787 -0.041081
# month_3                     -0.001057  0.003780  0.029055
# month_4                      0.000766  0.005595 -0.041845
# month_5                     -0.001057  0.003780  0.029055
# month_6                      0.000766  0.005595 -0.041845
# month_7                     -0.001057  0.003780  0.029055
# month_8                     -0.001057  0.003780  0.029055
# month_9                      0.002646  0.007468 -0.041081
# month_10                    -0.001057  0.003780  0.029055
# month_11                     0.000766  0.005595 -0.041845
# month_12                    -0.001057  0.003780  0.029055
# day_1                       -0.033994 -0.032501 -0.025782
# day_2                       -0.033994 -0.032501 -0.025782
# day_3                       -0.033994 -0.032501 -0.025782
# day_4                       -0.033994 -0.032501 -0.025782
# day_5                       -0.033994 -0.032501 -0.025782
# day_6                       -0.033994 -0.032501 -0.025782
# day_7                       -0.032501 -0.031073 -0.024649
# day_8                       -0.033994 -0.032501 -0.025782
# day_9                       -0.033994 -0.032501 -0.025782
# day_10                      -0.033994 -0.032501 -0.025782
# day_11                      -0.033994 -0.032501 -0.025782
# day_12                      -0.033994 -0.032501 -0.025782
# day_13                      -0.033994 -0.032501 -0.025782
# day_14                      -0.033994 -0.032501 -0.025782
# day_15                      -0.033994 -0.032501 -0.025782
# day_16                      -0.033994 -0.032501 -0.025782
# day_17                      -0.033994 -0.032501 -0.025782
# day_18                      -0.033994 -0.032501 -0.025782
# day_19                      -0.033994 -0.032501 -0.025782
# day_20                      -0.033994 -0.032501 -0.025782
# day_21                      -0.033994 -0.032501 -0.025782
# day_22                      -0.033994 -0.032501 -0.025782
# day_23                      -0.033994 -0.032501 -0.025782
# day_24                      -0.033994 -0.032501 -0.025782
# day_25                      -0.033994 -0.032501 -0.025782
# day_26                      -0.033994 -0.032501 -0.025782
# day_27                      -0.033994 -0.032501 -0.025782
# day_28                      -0.033994 -0.032501 -0.025782
# day_29                       1.000000 -0.032501 -0.025782
# day_30                      -0.032501  1.000000 -0.024649
# day_31                      -0.025782 -0.024649  1.000000
#
# [55 rows x 55 columns]

# %%
plt.subplots(figsize=(60,50))
df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Reds')

# %%
# Out:
# 0      37660
# 1      42029
# 2      43257
# 3      45681
# 4      45643
#        ...
# 360    60183
# 361    64677
# 362    68430
# 363    69293
# 364    74621
# Name: counts, Length: 365, dtype: int64
